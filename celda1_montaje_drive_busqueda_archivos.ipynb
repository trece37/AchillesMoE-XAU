# %% [markdown]
# <a href="https://colab.research.google.com/github/trece37/AchillesMoE-XAU/blob/main/celda1_montaje_drive_busqueda_archivos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
from google.colab import drive

# 1. MONTAR GOOGLE DRIVE
# Esto te pedirá permiso y abrirá una ventana para autenticar tu cuenta.
drive.mount('/content/drive')
print("\n--- Google Drive montado exitosamente. ---")

# 2. RUTA DE TU PROYECTO
# ⚠️ IMPORTANTE: Reemplaza 'MiCarpetaProyecto' por el nombre real de tu proyecto
# La ruta base es siempre: '/content/drive/MyDrive/'
FOLDER_PATH = '/content/drive/MyDrive/AchillesTraining'

# 3. FUNCIÓN PARA IMPRIMIR LA ESTRUCTURA EN FORMA DE ÁRBOL
def print_directory_tree(startpath):
    """Recorre y muestra la estructura de carpetas y archivos."""
    print(f"\n--- Estructura de la carpeta '{os.path.basename(startpath)}' ---")

    if not os.path.exists(startpath):
        print(f"❌ ERROR: La ruta no existe: {startpath}")
        print("Asegúrate de haber escrito correctamente el nombre de la carpeta.")
        return

    for root, dirs, files in os.walk(startpath):
        # Calcula el nivel de profundidad de la carpeta actual
        # y elimina la ruta de inicio para calcular la indentación
        relative_path = root.replace(startpath, '', 1)
        level = relative_path.count(os.sep)

        # Define la indentación: 4 espacios por nivel de profundidad
        indent = ' ' * 4 * level

        # Imprime el nombre de la carpeta actual
        print(f'{indent}├── {os.path.basename(root)}/')

        # Imprime los archivos dentro de la carpeta actual
        subindent = ' ' * 4 * (level + 1)
        for f in files:
            print(f'{subindent}├── {f}')

# EJECUCIÓN
print_directory_tree(FOLDER_PATH)
# Out:
# Mounted at /content/drive
#
# --- Google Drive montado exitosamente. ---
#
# --- Estructura de la carpeta 'AchillesTraining' ---
# ├── AchillesTraining/
#     ├── INVESTIGACION EN PROFUNDIDAD - Creación de Bot MetaTrader para Forex y Cripto.txt.MD
#     ├── COLAB.LISTAR _ARCHIVOS.IPYNB
#     ├── posible_estructura_carpetas_proyecto.txt
#     ├── RUTAS DE GOOGLE DRIVE (AchillesTraining).txt
#     ├── CITA_01_RESUMEN.md
#     ├── INFORME_JARVIS.01.MD
#     ├── scaler_v4_5_blindado.pkl
#     ├── achilles_blindado.keras
#     ├── data/
#         ├── XAUUSD_D1_2000-2009_DotCom-Lehman.csv
#         ├── XAUUSD_D1_2022_Ukraine.csv
#         ├── XAUUSD_D1_2020_COVID.csv
#         ├── XAUUSD_D1_2011-2012_Euro.csv
#         ├── XAUUSD_D1_2025_Volatility.csv
#         ├── XAUUSD_M5_2020-2025_Execution.csv
#         ├── MACRO_FEATURES_D1.csv
#         ├── XAUUSD_D1.csv
#         ├── XAUUSD_H4.csv
#         ├── MACRO_D1.csv
#     ├── output/
#         ├── v3.1/
#             ├── achilles_scaler_v3.1.0.pkl
#             ├── model_metadata_v3.1.0.json
#             ├── achilles_scaler.pkl
#             ├── best_model.keras
#             ├── achilles_model_export/
#                 ├── saved_model.pb
#                 ├── fingerprint.pb
#                 ├── variables/
#                     ├── variables.index
#                     ├── variables.data-00000-of-00001
#                 ├── assets/
#         ├── v4.0/
#         ├── v4_oro_puro/
#             ├── oro_puro_scaler.pkl
#             ├── oro_puro_best.keras
#             ├── achilles_oro_puro_final.keras
#     ├── v2/
#         ├── output/
#         ├── data/
#     ├── v1/
#         ├── output/
#         ├── data/
#     ├── v3/
#         ├── data/
#         ├── output/
#     ├── INSTANCIAS DE INVESTIGACION/
#         ├── Footprint Chart_ Trading Bot Insights.md
#         ├── DeepSeek-Construyendo Bot de Trading IA para XAU_USD.md
#         ├── DeepSeek-Construyendo Bot de Trading IA para XAU_USD.html
#         ├── gemini3-achillesMoE_ Chat.md
#         ├── instancia completa gemini3 achillesmoe - comprobar rutas y archivos.md
#         ├── chat-Guía Didáctica para Trading Bot XAU_USD (1).txt
#         ├── chat-Guía Didáctica para Trading Bot XAU_USD NAUTYLUS.txt
#     ├── INSTANCIAS de IA- INVESTIGACIONES PROFUNDAS SOBRE XAUUSD TRADING G CLOUD VERTEX -  CFGs ALTERNATIVAS para extraer informacion/
#         ├── Guía Completa de Implementación_ Desde el Prototipado en AI Studio a la Producción en Google Cloud y Firebase.pdf
#         ├── INVESTIGACION EN PROFUNDIDAD - Creación de Bot MetaTrader para Forex y Cripto.txt.MD
#         ├── INPUT-COMET-GCP-TRADING-SETUP.md
#         ├── __GUÍA ESTRATÉGICA FASE 1_ SELECCIÓN Y ANÁLISIS DE.md
#         ├── GUIA-COMPLETA-3-NOTEBOOKS-NOTEBOOKLM.md
#         ├── Guía Completa_ NotebookLM y_ Arquitectura para Bot.pdf
#         ├── USD-1.pdf
#         ├── DEEPRESEARCH-BOT.VERTEX-METATRADER.pdf
#         ├── INFORME-EJECUTIVO-BOT-TRADING-30-PAGINAS.pdf
#         ├── NOTEBOOK-1-CEREBRO-CONFIGURACION.md
#         ├── NOTEBOOK-2-OBRERO-CONFIGURACION.md
#         ├── estructura_proyecto.txt
#         ├── requirements.txt
#         ├── INFORME-ACHILLES.md
#         ├── Metodologías Deep Learning para Trading XAU_USD-2.pdf
#         ├── Revisión Completa - Proyecto LLM1337 ✅ (1).md
#         ├── las 3 reglas.txt
#     ├── INSTANCIAS CON ULTIMOS APORTES DE DIVERSAS IAS (REQUIERE UNIFICAR)/
#         ├── chat-Enciclopedia de Código 03_ Evolución del Proyecto AchillesMoE-XAU - deepseek (2).txt
#         ├── chat-Enciclopedia de Código 02_ Evolución del Proyecto AchillesMoE-XAU - gemini3 (1).txt
#         ├── Variables y configuraciones bot MetaTrader.md
#         ├── Enciclopedia Estratégica de Configuración para Sistemas de Trading Avanzados en MetaTrader 5.pdf
#         ├── chat-Guía Didáctica para Trading Bot XAU_USD NAUTYLUS.txt
#         ├── chat-Guía Didáctica para Trading Bot XAU_USD.txt
#         ├── instancia completa gemini3 achillesmoe - comprobar rutas y archivos(1).md
#         ├── gemini3-achillesMoE_ Chat(1).md
#         ├── DeepSeek-Construyendo Bot de Trading IA para XAU_USD.html
#         ├── Footprint Chart_ Trading Bot Insights.md
#         ├── chat-Enciclopedia de Código 01_ Evolución del Proyecto AchillesMoE-XAU - qwen3 (1).txt
#         ├── 001.REUNION DE LAS 5 INSTANCIAS METATRADER QWEN + GEMINI + DEEPSEEK.MD
#     ├── achilles_trading_bot/
#         ├── requirements.txt
#         ├── data/
#             ├── processed/
#             ├── raw/
#                 ├── XAUUSD_1h_20251212.csv
#         ├── src/
#             ├── worker/
#                 ├── Experts/
#                     ├── Achilles_v1.mq5
#                 ├── Include/
#                     ├── Json.mqh
#             ├── brain/
#                 ├── connections/
#                     ├── data_fetcher.py
#                 ├── api/
#                     ├── main.py
#                 ├── strategy/
#                     ├── roi.py
#                     ├── protection.py
#                 ├── training/
#                     ├── colab_notebook.py
#                 ├── core/
#                     ├── types.py
#                     ├── interfaces.py
#                 ├── models/
#                     ├── lstm.py
#                     ├── portfolio.py
#                     ├── seldon.py
#         ├── notebooks/
#             ├── Achilles_Training.ipynb
#         ├── docs/
#         ├── config/
#             ├── settings.py
#         ├── research/
#             ├── bot_ranking_analysis.md
#         ├── tests/
#             ├── test_advanced_features.py
#             ├── test_seldon_api.py
#     ├── INSTRUCCIONES PARA ANTIGRAVITY Y VARIABLES METATRADER Y LSTM/
#         ├── Enciclopedia Estratégica de Configuración para Sistemas de Trading Avanzados en MetaTrader 5.pdf
#         ├── Antigravity + File Search + CSV para tu bot de trading.pdf
#         ├── ChatGPT-Variables y configuraciones bot MetaTrader.pdf
#         ├── LEEME ANTIGRAVITY.TXT
#         ├── 00000.Todas las fuentes - oropuro1.TXT
#         ├── Enciclopedia Estratégica trading automatizado Antigravity.MD
#         ├── 00000.Todas las fuentes - oropuro1
#         ├── Requirements Achilles MoE.html
#     ├── ENTREGA_CITA_01/
#         ├── CODE_DUMP.md
#         ├── INSTRUCCIONES_CONTEXTO.md
#         ├── INFORME_EJECUTIVO_MANEL.md
#         ├── 4RULES.txt
#         ├── HISTORIAL_CONVERSACION_13DIC2025.md
#         ├── HISTORIAL_CONVERSACION_13DIC2025_UTF8.md
#         ├── antigravity-jarvis.md
#         ├── CONTEXTO_MASTER_MANEL_Y_LISTA.md
#         ├── JARVIS_CORE_PROTOCOL.md
